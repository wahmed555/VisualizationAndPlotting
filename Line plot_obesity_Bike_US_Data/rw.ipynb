# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("w.xlsx")

# %%
df
# Out:
#                  City_Alt Population_x  Total Points  Obesity Rank
# 0          SPRINGDALE, AR       77,252           3.0          35.7
# 1          SOUTH BEND, IN      101,928           2.0          38.6
# 2           KALAMAZOO, MI       75,833           1.9          37.4
# 3         SPRINGFIELD, MO      165,785           1.9          32.4
# 4             MEDFORD, OR       79,246           1.9          28.1
# 5          FORT WAYNE, IN      262,450           1.9          34.8
# 6          RAPID CITY, SD       72,841           1.9          28.0
# 7            MISSOULA, MT       70,847           2.2          24.5
# 8            WAUKESHA, WI       72,173           1.9          28.9
# 9                BEND, OR       87,167           2.0          26.0
# 10         BELLINGHAM, WA       85,388           2.1          27.6
# 11             TUSTIN, CA       80,007           1.7          21.6
# 12       FORT COLLINS, CO      159,150           3.6          21.6
# 13          IOWA CITY, IA       73,415           2.1          25.3
# 14          HILLSBORO, OR      102,396           2.3          29.2
# 15       MURFREESBORO, TN      126,188           1.7          29.7
# 16            REDDING, CA       91,236           1.6          25.4
# 17            WICHITA, KS      389,054           1.8          31.3
# 18            BOULDER, CO      106,271           3.7          14.9
# 19      SANTA BARBARA, CA       91,443           3.1          23.8
# 20         FORT SMITH, AR       87,537           1.7          35.0
# 21     MOUNT PLEASANT, SC       80,661           1.7          24.8
# 22          ANN ARBOR, MI      119,303           3.0          23.4
# 23               OREM, UT       94,420           1.8          25.6
# 24              TAMPA, FL      368,087           1.5          28.5
# 25       INDEPENDENCE, MO      117,369           1.7          31.2
# 26            LANSING, MI      115,222           1.8          38.1
# 27             AURORA, IL      200,946           2.0          34.4
# 28         CHARLESTON, WV       49,384           1.6          37.0
# 29        KANSAS CITY, KS      151,042           1.6          43.6
# ..                    ...          ...           ...           ...
# 235           EL PASO, TX      678,266           1.2          34.5
# 236           TRENTON, NJ       84,867           1.3          38.9
# 237          LAKEWOOD, CO      151,411           1.4          24.2
# 238            FRESNO, CA      519,037           1.3          33.7
# 239           WARWICK, RI       81,218           1.2          28.7
# 240       SIMI VALLEY, CA      126,546           1.4          23.1
# 241          O'FALLON, MO       85,246           1.4          31.4
# 242       WEST JORDAN, UT      111,937           1.2          25.9
# 243          MERIDIAN, ID       91,917           1.2          25.0
# 244           ROSWELL, GA       94,239           1.2          22.1
# 245             TEMPE, AZ      178,339           1.6          24.7
# 246              RENO, NV      239,732           1.5          25.7
# 247         BEAVERTON, OR       95,710           1.6          28.5
# 248      CEDAR RAPIDS, IA      130,330           1.7          32.2
# 249           CONCORD, NC       87,607           1.1          33.1
# 250          COLUMBIA, SC      132,236           1.3          31.5
# 251        SIOUX CITY, IA       82,568           1.3          36.2
# 252          LONGMONT, CO       91,730           1.4          18.2
# 253        CHESAPEAKE, VA      235,410           1.3          32.8
# 254            KENNER, LA       67,253           1.3          33.5
# 255         SAN DIEGO, CA    1,390,966           3.0          19.8
# 256            NORMAN, OK      119,820           1.6          30.0
# 257         JONESBORO, AR       73,581           1.1          35.2
# 258      SANTA MONICA, CA       92,495           3.1          20.6
# 259         HENDERSON, NV      284,817           1.4          23.8
# 260       BLOOMINGTON, IN       83,636           1.7          25.8
# 261          ROCKFORD, IL      148,640           1.3          36.3
# 262       CLARKSVILLE, TN      147,771           1.1          36.5
# 263          CHEYENNE, WY       62,986           1.2          29.2
# 264  WEST VALLEY CITY, UT      135,546           1.1          29.2
#
# [265 rows x 4 columns]

# %%
linechart = plt.plot(df['City_Alt'][:5], df['Population_x'][:5], color='blue')
plt.show()

# %%
# binning of bike score distribution 
bins_bike = [0, .4, .9, 1.4, 1.9, 2.4, 2.9, 3.4, 3.9, 8]
bins_name = ['<.5', '.5-.9', '1-1.4', '1.5-1.9', '2-2.4','2.5-2.9','3-3.4', '3.5-3.9', '>4']

#slice dtat and plact into bins
df['Total Points'] = pd.cut(df["Total Points"], bins_bike, labels=bins_name)

# %%
df['Total Points']
# Out:
# 0        3-3.4
# 1        2-2.4
# 2      1.5-1.9
# 3      1.5-1.9
# 4      1.5-1.9
# 5      1.5-1.9
# 6      1.5-1.9
# 7        2-2.4
# 8      1.5-1.9
# 9        2-2.4
# 10       2-2.4
# 11     1.5-1.9
# 12     3.5-3.9
# 13       2-2.4
# 14       2-2.4
# 15     1.5-1.9
# 16     1.5-1.9
# 17     1.5-1.9
# 18     3.5-3.9
# 19       3-3.4
# 20     1.5-1.9
# 21     1.5-1.9
# 22       3-3.4
# 23     1.5-1.9
# 24     1.5-1.9
# 25     1.5-1.9
# 26     1.5-1.9
# 27       2-2.4
# 28     1.5-1.9
# 29     1.5-1.9
#         ...
# 235      1-1.4
# 236      1-1.4
# 237      1-1.4
# 238      1-1.4
# 239      1-1.4
# 240      1-1.4
# 241      1-1.4
# 242      1-1.4
# 243      1-1.4
# 244      1-1.4
# 245    1.5-1.9
# 246    1.5-1.9
# 247    1.5-1.9
# 248    1.5-1.9
# 249      1-1.4
# 250      1-1.4
# 251      1-1.4
# 252      1-1.4
# 253      1-1.4
# 254      1-1.4
# 255      3-3.4
# 256    1.5-1.9
# 257      1-1.4
# 258      3-3.4
# 259      1-1.4
# 260    1.5-1.9
# 261      1-1.4
# 262      1-1.4
# 263      1-1.4
# 264      1-1.4
# Name: Total Points, Length: 265, dtype: category
# Categories (9, object): [<.5 < .5-.9 < 1-1.4 < 1.5-1.9 ... 2.5-2.9 < 3-3.4 < 3.5-3.9 < >4]

# %%
type(df['Total Points'])
# Out:
# pandas.core.series.Series

# %%
bin_group_bike = df.groupby('Total Points')
bin_group_bike

# %%
count_cat = bin_group_bike['Total Points'].count()
count_cat
# Out:
# Total Points
# <.5          0
# .5-.9        1
# 1-1.4       94
# 1.5-1.9    115
# 2-2.4       22
# 2.5-2.9     14
# 3-3.4       17
# 3.5-3.9      2
# >4           0
# Name: Total Points, dtype: int64

# %%
#create new df to show bin df
bike_analysis_df = pd.DataFrame(count_cat)
bike_analysis_df
# Out:
#               Total Points
# Total Points
# <.5                      0
# .5-.9                    1
# 1-1.4                   94
# 1.5-1.9                115
# 2-2.4                   22
# 2.5-2.9                 14
# 3-3.4                   17
# 3.5-3.9                  2
# >4                       0

# %%
y = [2.56422, 3.77284, 3.52623, 3.51468, 3.02199]
z = [0.15, 0.3, 0.45, 0.6, 0.75]
n = [58, 651, 393, 203, 123]

fig, ax = plt.subplots()
ax.scatter(z, y)

for i, txt in enumerate(n):
    ax.annotate(txt, (z[i], y[i]))

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0.0, 1.0 + 0.01, 0.01)
s = np.cos(2 * 2*np.pi * t)
t[41:60] = np.nan

plt.subplot(1, 2, 1)
plt.plot(t, s, '-', lw=2)

plt.xlabel('time (s)')
plt.ylabel('voltage (mV)')
plt.title('A sine wave with a gap of NaNs between 0.4 and 0.6')
plt.grid(True)

plt.subplot(1, 2, 2)
t[0] = np.nan
t[-1] = np.nan
plt.plot(t, s, '-', lw=2)
plt.title('Also with NaN in first and last point')

plt.xlabel('time (s)')
plt.ylabel('more nans')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
plt.subplot(1, 2, 1)
plt.plot(t, s, '-', lw=2)

plt.xlabel('time (s)')
plt.ylabel('voltage (mV)')
plt.title('A sine wave with a gap of NaNs between 0.4 and 0.6')
plt.grid(True)

plt.subplot(1, 2, 2)
t[0] = np.nan
t[-1] = np.nan
plt.plot(t, s, '-', lw=2)
plt.title('Also with NaN in first and last point')

plt.xlabel('time (s)')
plt.ylabel('more nans')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.ticker import NullFormatter  # useful for `logit` scale

# Fixing random state for reproducibility
np.random.seed(19680801)

# make up some data in the interval ]0, 1[
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# plot with various axes scales
plt.figure()

# linear
plt.subplot(121)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)


# log
plt.subplot(122)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)
